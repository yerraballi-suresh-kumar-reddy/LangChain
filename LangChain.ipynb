# %%
pip install python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement python (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for python

# %%
# !python --version
# Out:
# Python 3.13.5

# %%
pip install langchain langchain-community
# Out:
# ...
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# ...
#   Using cached sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...

# %%
pip install langchain-text-splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-aws
# Out:
# ...
#   Using cached langchain_aws-0.2.31-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached s3transfer-0.13.1-py3-none-any.whl.metadata (1.7 kB)
# ...
# Using cached langchain_aws-0.2.31-py3-none-any.whl (141 kB)
# ...
#    ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/14.0 MB 10.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.0 MB 10.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.3/14.0 MB 10.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.4/14.0 MB 10.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.2/14.0 MB 9.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.3/14.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.0/14.0 MB 9.3 MB/s eta 0:00:00
# ...

# %%
pip install boto3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_aws import ChatBedrock

# %%
from langchain_aws import ChatBedrockConverse

# %%
import os
os.environ['AWS_BEARER_TOKEN_BEDROCK'] = "bedrock-api-key-..."

# %%
llm=ChatBedrockConverse(model_id='apac.anthropic.claude-3-haiku-20240307-v1:0',
                        region_name='ap-south-1')

# %%
message=[
    (
        'system',
        'you are a helpfull assistant'
    ),
    (
        "human",
        "The sky is?"
    )
]

# %%
response=llm.invoke(message)

# %%
response.content
# Out:
# 'Blue.'

# %%
#stream the response
for chunk in llm.stream(message):
    print(chunk.text())
# Out:
# The
#  sky
#  is blue.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

# %%
system_msg=SystemMessage(
    '''you are a helpful assistant
'''
)

# %%
humanmsg=HumanMessage('what is cloud computing?')

# %%
llm.invoke([system_msg,humanmsg])
# Out:
# AIMessage(content='Cloud computing refers to the delivery of computing services - including servers, storage, databases, networking, software, analytics, and intelligence - over the internet ("the cloud") to offer faster innovation, flexible resources, and economies of scale.\n\nHere are the key characteristics of cloud computing:\n\n1. On-demand availability: Cloud resources can be rapidly provisioned and released with minimal management effort or service provider interaction.\n\n2. Broad network access: Computing capabilities are available over the network and accessed through standard mechanisms.\n\n3. Resource pooling: The provider\'s computing resources are pooled to serve multiple consumers using a multi-tenant model, with different physical and virtual resources dynamically assigned and reassigned according to demand.\n\n4. Rapid elasticity: Capabilities can be rapidly and elastically provisioned, in some cases automatically, to scale rapidly outward and inward commensurate wi
# ...

# %%
from langchain_core.prompts import PromptTemplate

# %%
template=PromptTemplate.from_template("Answer the question based on give content, if not found from the context say Dont know, print the answer in Answer" \
"context={context}" \
"question={question}" \
"Answer: ")

# %%
prompt=template.invoke({
    "context":"Bangalore is a green city",
    "question":"is bangalore green city?"
})

# %%
response=llm.invoke(prompt)

# %%
response
# Out:
# AIMessage(content='Answer: Yes, Bangalore is a green city.', additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'cce4d219-3b69-4541-afc2-8235c0601025', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 07 Sep 2025 14:01:41 GMT', 'content-type': 'application/json', 'content-length': '220', 'connection': 'keep-alive', 'x-amzn-requestid': 'cce4d219-3b69-4541-afc2-8235c0601025'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [828]}, 'model_name': 'apac.anthropic.claude-3-haiku-20240307-v1:0'}, id='run--ff8ba4af-5ad6-4321-ad1b-87297d7424f9-0', usage_metadata={'input_tokens': 53, 'output_tokens': 14, 'total_tokens': 67, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
template=ChatPromptTemplate.from_messages(
    [
        (
            'system','Answer the question based on give context below, if the question can not be answered using the context information provided, Anawer with "Dont know"'
        ),
        (
            'human','Context:{context}'
        ),
        (
            'human','Question:{question}'
        ),
    ])

# %%
prompt=template.invoke(
    {
        "context":"bangalore is a green city",
        "question":"what is 2+2?"
    }
)

# %%
response=llm.invoke(prompt)

# %%
response
# Out:
# AIMessage(content='The context provided about Bangalore being a green city does not contain any information to answer the question "what is 2+2?". The context is not relevant to solving a simple arithmetic problem. Therefore, the answer is: Don\'t know.', additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'c06f7e16-69c4-4e43-8070-99750387fda9', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 07 Sep 2025 14:23:00 GMT', 'content-type': 'application/json', 'content-length': '418', 'connection': 'keep-alive', 'x-amzn-requestid': 'c06f7e16-69c4-4e43-8070-99750387fda9'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [1285]}, 'model_name': 'apac.anthropic.claude-3-haiku-20240307-v1:0'}, id='run--5ff0e433-6262-4b0b-b9a9-3610fb69e262-0', usage_metadata={'input_tokens': 56, 'output_tokens': 53, 'total_tokens': 109, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})

# %%
#output format

# %%
from langchain_core.pydantic_v1 import BaseModel

# %%
llm=ChatBedrockConverse(model_id='apac.anthropic.claude-3-haiku-20240307-v1:0',
                        region_name='ap-south-1',temperature=0)

# %%
class AnswerWithJustification(BaseModel):
    answer: str
    justification:str
structuredllm=llm.with_structured_output(AnswerWithJustification)
structuredllm.invoke('What weighs more, a pound of bricks or a pound of feathers')
# Out:
# AnswerWithJustification(answer='A pound of bricks and a pound of feathers weigh the same amount.', justification='This is because a pound is a unit of weight, and by definition, a pound of any material will weigh the same, regardless of the material. The weight of an object is determined by the amount of matter it contains, not the type of material. So a pound of bricks and a pound of feathers will both weigh exactly one pound.')

# %%
response=llm.invoke("what is the time?")

# %%
print(type(response.content))
# Out:
# <class 'str'>

# %%
print(response)
# Out:
# content="I don't actually have a way to check the current time. As an AI assistant without access to a clock or calendar, I don't have a way to provide the current time. I can only respond based on the information and capabilities I've been given by my creators at Anthropic. If you need to know the current time, I'd suggest checking a clock, watch, or your device's time display." additional_kwargs={} response_metadata={'ResponseMetadata': {'RequestId': '9ef80bf2-7400-4064-a1d2-e65b70be7789', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 07 Sep 2025 15:18:53 GMT', 'content-type': 'application/json', 'content-length': '554', 'connection': 'keep-alive', 'x-amzn-requestid': '9ef80bf2-7400-4064-a1d2-e65b70be7789'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [1690]}, 'model_name': 'apac.anthropic.claude-3-haiku-20240307-v1:0'} id='run--36f1f2ea-03c0-4d76-83cc-08c7e0676c6d-0' usage_metadata={'input_tokens': 12, 'output_tokens': 87, 'total_tokens': 99, 'in
# ...

# %%
from langchain_core.pydantic_v1 import BaseModel

class AnswerWithJustification(BaseModel):
    '''An answer to the user's question along with justification for the 
        answer.'''
    answer: str
    '''The answer to the user's question'''
    justification: str
    '''Justification for the answer'''

structured_llm = llm.with_structured_output(AnswerWithJustification)

structured_llm.invoke("""What weighs more, a pound of bricks or a pound 
    of feathers""")
# Out:
# AnswerWithJustification(answer='A pound of bricks and a pound of feathers weigh the same amount.', justification="This is because a pound is a unit of weight, not volume. By definition, a pound of any material, whether it's bricks or feathers, will weigh the same - one pound. The volume and density of the materials may be different, but the weight of one pound is the same.")

# %%
response=llm.batch(["what is 2+2","what is 4+3?"])

# %%
response
# Out:
# [AIMessage(content='4', additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'c3779e0e-2652-431f-bec2-7fbbe0161f57', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 07 Sep 2025 15:22:46 GMT', 'content-type': 'application/json', 'content-length': '181', 'connection': 'keep-alive', 'x-amzn-requestid': 'c3779e0e-2652-431f-bec2-7fbbe0161f57'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [655]}, 'model_name': 'apac.anthropic.claude-3-haiku-20240307-v1:0'}, id='run--597dafb7-5372-4712-9136-8d8a30761cce-0', usage_metadata={'input_tokens': 13, 'output_tokens': 5, 'total_tokens': 18, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}}),
# ...

# %% [markdown]
# Chapter 2 RAG - Document loader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader('./bangalore.txt')

# %%
content=loader.load()

# %%
print(type(content))
# Out:
# <class 'list'>

# %%
content
# Out:
# [Document(metadata={'source': './bangalore.txt'}, page_content='bangalore is a green city')]

# %%
len(content)
# Out:
# 1

# %%
content[0].page_content
# Out:
# 'bangalore is a green city'

# %%
pip install beautifulsoup4
# Out:
# ...
#
#    ---------------------------------------- 0/2 [soupsieve]
#    ---------------------------------------- 0/2 [soupsieve]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
loader=WebBaseLoader('https://www.cloudthat.com/resources/blog/scaling-reliable-text-summarization-with-llm-jury-systems-on-amazon-bedrock')

# %%
page=loader.load()

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
)

# %%
splitter=splitter.split_documents(page)

# %%
splitter[0].page_content
# Out:
# 'Scaling Reliable Text Summarization with LLM Jury Systems on Amazon Bedrock\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n +91 8880002200\n sales@cloudthat.com\n \n Login \nResources\nBlog\nCareers\nContact Us\n \n\n\n\n\n\n\n\n\n\n\n\n\n\nConsulting\n\nGenAI Innovation Center\nServices\n\nConsultancy and Migration\nContract Staffing\nData Analytics\nDevOps and DevSecOps\nManaged Services\nMedia Services\nApp Modernization\n\n\nExpertise'

# %%
pip install langchain_text_splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader=TextLoader('./bangalore.txt')

# %%
doc=loader.load()

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
)

# %%
splitter=splitter.split_documents(doc)

# %%
splitter[0].page_content
# Out:
# 'bangalore is a green city'

# %% [markdown]
# Embeddings

# %%
import os
os.environ['AWS_BEARER_TOKEN_BEDROCK'] = "bedrock-api-key-..."

# %%
from langchain_aws import BedrockEmbeddings

# %%
from langchain_aws import BedrockEmbeddings

embeddings = BedrockEmbeddings(
    region_name="ap-south-1",
    model_id="amazon.titan-embed-text-v2:0"  # Specify the Titan model here
)

# %%
embeddings = embeddings.embed_documents([
    "Hi there!",
    "Oh, hello!",
    "What's your name?",
    "My friends call me World",
    "Hello World!"
])

# %%
embeddings
# Out:
# [[-0.05407876521348953,
#   0.06885949522256851,
#   0.016753489151597023,
#   0.006643473170697689,
#   0.01691705547273159,
#   -0.03248337283730507,
#   0.06673958897590637,
#   -0.059997621923685074,
#   0.0356866829097271,
#   -0.05202217027544975,
#   0.020214755088090897,
#   0.036901410669088364,
#   0.033504631370306015,
#   -0.004169172141700983,
#   -0.0025326337199658155,
#   -0.0038833715952932835,
#   0.015624943189322948,
#   -0.015718743205070496,
#   -0.012334863655269146,
#   -2.638160003698431e-05,
#   0.03684278577566147,
#   0.016138505190610886,
#   0.03731999918818474,
#   0.007914479821920395,
#   -0.05146053805947304,
#   -0.024219481274485588,
#   0.020683174952864647,
#   -0.014586093835532665,
#   0.024659467861056328,
#   -0.0027999673038721085,
#   0.09870177507400513,
#   0.09556031227111816,
#   0.019055724143981934,
#   0.014173367992043495,
#   0.0039396523497998714,
#   0.06847754865884781,
#   0.043345555663108826,
#   0.005154378712177277,
# ...

# %%
loader=TextLoader('./bangalore.txt')

# %%
doc=loader.load()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=20,
)
chunks = text_splitter.split_documents(doc)

# %%
pcontent=chunks[0].page_content

# chunk in pcontent:
#     chunk

# %%
print(type(pcontent))
# Out:
# <class 'str'>

# %%
for word in pcontent.split():
    print(word)
# Out:
# bangalore
# is
# a
# green
# city

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=20,
)
chunks = text_splitter.split_documents(doc)

# %%
embeddings = embeddings.embed_documents(
    [chunk.page_content for chunk in chunks]
)

# %%
embeddings
# Out:
# [[-0.03890468180179596,
#   0.08435224741697311,
#   0.007197806145995855,
#   -0.053546857088804245,
#   -0.010197306983172894,
#   0.013651401735842228,
#   0.04008762538433075,
#   0.02736535109579563,
#   -0.016283784061670303,
#   -0.0031177953351289034,
#   0.09399253129959106,
#   -0.00541342468932271,
#   -0.024791888892650604,
#   0.01666993834078312,
#   0.008297803811728954,
#   -0.020279832184314728,
#   -0.0171499140560627,
#   -0.005192246288061142,
#   -0.009780786000192165,
#   0.014580531977117062,
#   0.013005543500185013,
#   -0.07823722064495087,
#   -0.010477859526872635,
#   -0.018869595602154732,
#   -0.021502317860722542,
#   -0.005634602624922991,
#   -0.033064309507608414,
#   -0.05350515991449356,
#   0.022415131330490112,
#   -0.004686437547206879,
#   0.04376063123345375,
#   -0.02311129868030548,
#   -0.007210043724626303,
#   -0.026142526417970657,
#   0.03263283148407936,
#   0.003982112277299166,
#   -0.018441176041960716,
#   -0.042088255286216736,
# ...

# %%
pip install langchain_postgres
# Out:
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/621.6 kB ? eta -:--:--
#    ---------------------------------------- 621.6/621.6 kB 3.1 MB/s eta 0:00:00
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ---------------------------------------- 0/6 [tzdata]
#    ------ --------------------------------- 1/6 [psycopg-pool]
#    ------ --------------------------------- 1/6 [psycopg-pool]
#    ------ --------------------------------- 1/6 [psycopg-pool]
#    ------ --------------------------------- 1/6 [psycopg-pool]
#    ------------- -------------------------- 2/6 [pgvector]
#    ------------- -------------------------- 2/6 [pgvector]
#    ------------- -------------------------- 2/6 [pgvector]
#    ------------- -------------------------- 2/6 [pgvector]
# ...

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_postgres.vectorstores import PGVector
from langchain_core.documents import Document
import uuid

# %%
# Load the document, split it into chunks
raw_documents = TextLoader('./bangalore.txt').load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, 
    chunk_overlap=200)
documents = text_splitter.split_documents(raw_documents)
# embed each chunk and insert it into the vector store

# %%
from langchain_aws import BedrockEmbeddings

embeddings_model = BedrockEmbeddings(
    region_name="ap-south-1",
    model_id="amazon.titan-embed-text-v2:0"  # Specify the Titan model here
)

# %%
import os
os.environ['AWS_BEARER_TOKEN_BEDROCK'] = "bedrock-api-key-..."

# %%
connection = 'postgresql+psycopg://langchain:langchain@localhost:6024/langchain'
db = PGVector.from_documents(documents, embeddings_model, connection=connection)
# Out:
# Error raised by inference endpoint
# Traceback (most recent call last):
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\langchain_aws\embeddings\bedrock.py", line 198, in _invoke_model
#     response = self.client.invoke_model(
#         body=body,
#     ...<2 lines>...
#         contentType="application/json",
#     )
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# ...

# %%
db.similarity_search("query", k=4)
# Out:
# Error raised by inference endpoint
# Traceback (most recent call last):
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\langchain_aws\embeddings\bedrock.py", line 198, in _invoke_model
#     response = self.client.invoke_model(
#         body=body,
#     ...<2 lines>...
#         contentType="application/json",
#     )
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\YerraballiSureshKuma\Downloads\Learning\LangChain\venv\Lib\site-packages\botocore\client.py", line 1078, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# ...

# %%
SELECT indexname, indexdef
FROM pg_indexes
WHERE tablename = 'langchain_document';
# Out:
#   Cell In[14], line 1
#     SELECT indexname, indexdef
#            ^
# SyntaxError: invalid syntax
